# %%
import pandas as pd
import matplotlib as mpl
# %matplotlib inline

# %%
filename = r'C:\Users\JEANLUCCAPIERROSANTO\Downloads\dados_deput_eleitos\TSE_DEPUTADO_FEDERAL_BR_CANDIDATO_2010_2018.csv'
df = pd.read_csv(filename)

# %%
df.shape
# Out:
# (1539, 12)

# %%
df.sample(10)
# Out:
#       ANO_ELEICAO  NUM_TURNO SIGLA_UE   DESCRICAO_CARGO  \
# 1267         2018          1       SP  DEPUTADO FEDERAL
# 415          2010          1       MG  DEPUTADO FEDERAL
# 500          2010          1       RJ  DEPUTADO FEDERAL
# 922          2014          1       RS  DEPUTADO FEDERAL
# 1361         2018          1       PA  DEPUTADO FEDERAL
# 1220         2018          1       PI  DEPUTADO FEDERAL
# 1283         2018          1       MG  DEPUTADO FEDERAL
# 426          2010          1       PE  DEPUTADO FEDERAL
# 1071         2018          1       AC  DEPUTADO FEDERAL
# 704          2014          1       PA  DEPUTADO FEDERAL
#
#                         NOME_CANDIDATO  NUMERO_CANDIDATO  CPF_CANDIDATO  \
# 1267               MILTON VIEIRA PINTO              1055     4976912809
# 415         GABRIEL MOREIRA DE ANDRADE              1311     6313474619
# 500               ALFREDO HELIO SYRKIS              4333    69738866715
# 922            HENRIQUE FONTANA JUNIOR              1313    33410518053
# 1361          ÉDER MAURO CARDOSO BARRA              5500    13405551234
# 1220                 FÁBIO ABREU COSTA              2222    48140597368
# 1283           WELITON FERNANDES PRADO              9090    84719850634
# 426            JOAO PAULO LIMA E SILVA              1333     7993137420
# 1071  FLAVIANO FLAVIO BAPTISTA DE MELO              1555    33251797700
# 704                   LUCIO DUTRA VALE              2222    32205252291
#
#       NUMERO_PARTIDO SIGLA_PARTIDO  NUM_TITULO_ELEITORAL_CANDIDATO  \
# 1267              10           PRB                    151725170191
# 415               13            PT                    145469490221
# 500               43            PV                     16334830337
# 922               13            PT                     44194670469
# 1361              55           PSD                     10230281392
# 1220              22            PR                     27124241503
# 1283              90          PROS                    107212460230
# 426               13            PT                      2149600850
# 1071              15           MDB                       745162429
# 704               22            PR                     22853511309
#
#      DESC_SIT_TOT_TURNO  QTDE_VOTOS
# 1267      ELEITO POR QP       77413
# 415              ELEITO      137120
# 500    ELEITO POR MEDIA       73185
# 922       ELEITO POR QP      128981
# 1361      ELEITO POR QP      145653
# 1220      ELEITO POR QP      132719
# 1283   ELEITO POR MEDIA      129199
# 426              ELEITO      264250
# 1071   ELEITO POR MEDIA       18723
# 704       ELEITO POR QP      148163

# %%
df["QTDE_VOTOS"] = df["QTDE_VOTOS"].astype(float)

# %%
sum_votos_2010 = df.query('ANO_ELEICAO == 2010').groupby("SIGLA_PARTIDO").sum("QTDE_VOTOS")
sum_votos_2010.iloc[:, [6]]
# Out:
#                QTDE_VOTOS
# SIGLA_PARTIDO
# DEM             4550184.0
# PC do B         1823077.0
# PDT             2596556.0
# PHS               96060.0
# PMDB            8492579.0
# PMN              446162.0
# PP              5197306.0
# PPS             1356469.0
# PR              5889206.0
# PRB              871461.0
# PRP               47488.0
# PRTB              50488.0
# PSB             4737508.0
# PSC             1859443.0
# PSDB            6362262.0
# PSL               40093.0
# PSOL             442756.0
# PT             10472717.0
# PT do B          178734.0
# PTB             2349527.0
# PTC              104015.0
# PV              1005770.0

# %%
sum_votos_2010.nlargest(5, "QTDE_VOTOS").iloc[:, [6]]
# Out:
#                QTDE_VOTOS
# SIGLA_PARTIDO
# PT             10472717.0
# PMDB            8492579.0
# PSDB            6362262.0
# PR              5889206.0
# PP              5197306.0

# %%
df.query('ANO_ELEICAO == "2010"').groupby("SIGLA_PARTIDO").size().sort_values(ascending=False).plot(kind='bar', title="Candidatos eleitos por partido - 2010")
# Out:
# <AxesSubplot:title={'center':'Candidatos eleitos por partido - 2010'}, xlabel='SIGLA_PARTIDO'>

# %%
sum_votos_2014 = df.query('ANO_ELEICAO == 2014').groupby("SIGLA_PARTIDO").sum("QTDE_VOTOS")
sum_votos_2014.iloc[:, [6]]
# Out:
#                QTDE_VOTOS
# SIGLA_PARTIDO
# DEM             2743097.0
# PC do B          908509.0
# PDT             1821210.0
# PEN              107841.0
# PHS              297379.0
# PMDB            7279016.0
# PMN              133282.0
# PP              5125389.0
# PPS             1168957.0
# PR              4323988.0
# PRB             3076897.0
# PROS            1077566.0
# PRP              170865.0
# PRTB              64435.0
# PSB             3353611.0
# PSC             1519918.0
# PSD             3891277.0
# PSDB            7488390.0
# PSDC              83879.0
# PSL              107734.0
# PSOL             730097.0
# PT              7317384.0
# PT do B          173033.0
# PTB             2480986.0
# PTC               85285.0
# PTN              431340.0
# PV               626424.0
# SD              1543706.0

# %%
sum_votos_2014.nlargest(5, "QTDE_VOTOS").iloc[:, [6]]
# Out:
#                QTDE_VOTOS
# SIGLA_PARTIDO
# PSDB            7488390.0
# PT              7317384.0
# PMDB            7279016.0
# PP              5125389.0
# PR              4323988.0

# %%
df.query('ANO_ELEICAO == "2014"').groupby("SIGLA_PARTIDO").size().sort_values(ascending=False).plot(kind='bar', title="Candidatos eleitos por partido - 2014")
# Out:
# <AxesSubplot:title={'center':'Candidatos eleitos por partido - 2014'}, xlabel='SIGLA_PARTIDO'>

# %%
sum_votos_2018 = df.query('ANO_ELEICAO == 2018').groupby("SIGLA_PARTIDO").sum("QTDE_VOTOS")
sum_votos_2018.iloc[:, [6]]
# Out:
#                QTDE_VOTOS
# SIGLA_PARTIDO
# AVANTE           676035.0
# DC                50284.0
# DEM             2922440.0
# MDB             2869746.0
# NOVO             882961.0
# PATRI            421012.0
# PC do B          713572.0
# PDT             2569703.0
# PHS              346852.0
# PMN              270433.0
# PODE            1163224.0
# PP              3316348.0
# PPL               66343.0
# PPS              690037.0
# PR              3810249.0
# PRB             3269569.0
# PROS             837453.0
# PRP              229583.0
# PSB             3341657.0
# PSC              776834.0
# PSD             3738568.0
# PSDB            2598470.0
# PSL             7607558.0
# PSOL            1557490.0
# PT              6132826.0
# PTB              894351.0
# PTC              196669.0
# PV               508448.0
# REDE               8491.0
# SOLIDARIEDADE    849821.0

# %%
sum_votos_2018.nlargest(5, "QTDE_VOTOS").iloc[:, [6]]
# Out:
#                QTDE_VOTOS
# SIGLA_PARTIDO
# PSL             7607558.0
# PT              6132826.0
# PR              3810249.0
# PSD             3738568.0
# PSB             3341657.0

# %%
df.query('ANO_ELEICAO == "2018"').groupby("SIGLA_PARTIDO").size().sort_values(ascending=False).plot(kind='bar', title="Candidatos eleitos por partido - 2018")
# Out:
# <AxesSubplot:title={'center':'Candidatos eleitos por partido - 2018'}, xlabel='SIGLA_PARTIDO'>

# %%
df.query('ANO_ELEICAO == 2018 and SIGLA_UE == "SP"').groupby("SIGLA_PARTIDO").sum("QTDE_VOTOS").sample(19).iloc[:,[6]].plot(kind='pie', label="", subplots=True)
# Out:
# array([<AxesSubplot:ylabel='QTDE_VOTOS'>], dtype=object)
